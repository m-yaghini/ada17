# %%
import pandas as pd
import json
from IPython.display import display

# %% [markdown]
# # First Records: Radio Tranmission from 1949

# %%
with open('./dataset/per_year/1949/data_0.json', 'r') as f:
    data = json.load(f)
    _DF = pd.DataFrame(data['response']['docs'])

# %%
# print(json.dumps(data, indent=4, sort_keys=True))

display(DF.columns)
DF = _DF.drop(['alternativeExcerpt', 'alternativeTitle', 'articleURL', 'imageURL', 'isOnline'], axis=1)

DF.contributors.iloc[1]
display(DF)
# Out:
# Index(['contributors', 'durationSec', 'excerpt', 'genres', 'id', 'mediaType',
#        'mediaURL', 'program', 'publicationChannelNames', 'publicationDate',
#        'source', 'thematicGeographicals', 'thematicPersons', 'thematicThemes',
#        'title', 'variantIds'],
#       dtype='object')
#                                          contributors  durationSec  \
# 0   {'Traducteur/trice': [{'name': 'Fehlmann, Begn...          725
# 1   {'Interviewé/e': [{'role': 'Miss Germany 1950,...          186
# 2   {'Interviewé/e': [{'role': 'ministre belge des...          279
# 3   {'Interviewé/e': [{'role': 'athlète suisse', '...          245
# 4   {'Interviewé/e': [{'role': 'philosophe indien'...          632
# 5   {'Auteur du texte': [{'name': 'Shaw, Bernard',...          201
# 6   {'Commentateur/trice': [{'role': 'collaborateu...           85
# 7   {'Récitant/e': [{'role': 'comédien', 'name': '...           73
# 8   {'Commentateur/trice': [{'role': 'collaborateu...          154
# ...

# %%
with open('./dataset/per_year/1899/data_0.json', 'r') as f:
    data = json.load(f)
    _DF = pd.DataFrame(data['response']['docs'])

_DF
# Out:
#                                          contributors  durationSec  \
# 0                                                 NaN          406
# 1                                                 NaN          372
# 2                                                 NaN          524
# 3                                                 NaN          458
# 4                                                 NaN          306
# 5                                                 NaN          652
# 6                                                 NaN          231
# 7   {'Auteur d'une déclaration': [{'role': 'empere...           28
# 8                                                 NaN          520
# 9   {'Interviewé/e': [{'role': 'Empereur d'Autrich...           89
# 10                                                NaN          407
# 11                                                NaN          373
# 12  {'Récitant/e': [{'role': 'collaboratrice RSR',...         1005
# ...

# %%
_DF.iloc[10]
# Out:
# contributors                                                             NaN
# durationSec                                                              407
# excerpt                                                    Clémence dès 3.40
# genres                                                                   NaN
# id                                sound-DF4956B2-7E48-426F-9B63-54A5CA83E659
# isOnline                                                               False
# mediaType                                                              audio
# program                                                                  NaN
# publicationChannelNames                                                  NaN
# publicationDate                                         1900-01-01T00:00:00Z
# source                                                               siranau
# thematicGeographicals                                       [Genève (ville)]
# ...
